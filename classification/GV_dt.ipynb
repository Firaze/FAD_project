# %%
import dill
dill.load_session('C:/Users/ress/Desktop/Università/FAD/Passatempo/GV/FAD_project/notebook_env.db')

# %%
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier 
dt = DecisionTreeClassifier(max_depth=2)
dt.fit(data_train.drop('label',axis=1),data_train['label'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
cluster_test=dt.predict(data_test.drop('label',axis=1))
print("Classification Report\n",classification_report(data_test.label,cluster_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95       391
#            1       0.94      0.97      0.96       401
#
#     accuracy                           0.95       792
#    macro avg       0.96      0.95      0.95       792
# weighted avg       0.96      0.95      0.95       792

# %%
dot_data = tree.export_graphviz(dt, out_file=None,feature_names=data_train.columns[:-1],class_names=["male","female"],rotate=False, label='root') 
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# <h1> Without outliers

# %%
clean_dt = DecisionTreeClassifier(max_depth=2)
clean_dt.fit(data_clean_train.drop('label',axis=1),data_clean_train['label'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
cluster_test=clean_dt.predict(data_clean_test.drop('label',axis=1))
print("Classification Report\n",classification_report(data_clean_test.label,cluster_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       382
#            1       0.98      0.98      0.98       350
#
#     accuracy                           0.98       732
#    macro avg       0.98      0.98      0.98       732
# weighted avg       0.98      0.98      0.98       732

# %%
dot_data = tree.export_graphviz(clean_dt, out_file=None,feature_names=data_clean_train.columns[:-1],class_names=["male","female"],rotate=False, label='root') 
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# <h1>------------------------------------------------------------------------------------------------------PCA

# %%
pca_dt = DecisionTreeClassifier(max_depth=2)
pca_dt.fit(pca_train.drop('label',axis=1),pca_train['label'])
dot_data = tree.export_graphviz(pca_dt, out_file=None,feature_names=pca_train.columns[:-1],class_names=["male","female"],rotate=False, label='root') 
graph = graphviz.Source(dot_data)
graph

# %%
cluster_test=pca_dt.predict(pca_test.drop('label',axis=1))
print("Classification Report\n",classification_report(pca_test.label,cluster_test))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       382
#            1       0.99      0.94      0.96       350
#
#     accuracy                           0.97       732
#    macro avg       0.97      0.96      0.97       732
# weighted avg       0.97      0.97      0.97       732

# %%
dill.dump_session('C:/Users/ress/Desktop/Università/FAD/Passatempo/GV/FAD_project/notebook_env.db')
