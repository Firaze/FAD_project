# %%
import dill
dill.load_session('notebook_env.db')

# %%
kmeans_extra = KMeans(n_clusters=3)
kmeans_extra.fit(data_train[["meanfun","IQR"]])
aux=pd.DataFrame({"X":data["meanfun"],"Y":data["IQR"],"C":data["label"]})
data_extra=data_train.copy()
data_extra.label=kmeans_extra.labels_
plt.figure(figsize=(12,8))
plot_kmeans_decision_boundary(aux,kmeans_extra)
plt.legend()
plt.show()
