# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from matplotlib import pyplot as plt
data=pd.read_csv("Gender_voice.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
# meanfreq    3168 non-null float64
# sd          3168 non-null float64
# median      3168 non-null float64
# Q25         3168 non-null float64
# Q75         3168 non-null float64
# IQR         3168 non-null float64
# skew        3168 non-null float64
# kurt        3168 non-null float64
# sp.ent      3168 non-null float64
# sfm         3168 non-null float64
# mode        3168 non-null float64
# centroid    3168 non-null float64
# meanfun     3168 non-null float64
# minfun      3168 non-null float64
# maxfun      3168 non-null float64
# meandom     3168 non-null float64
# mindom      3168 non-null float64
# maxdom      3168 non-null float64
# dfrange     3168 non-null float64
# modindx     3168 non-null float64
# label       3168 non-null object
# dtypes: float64(20), object(1)
# memory usage: 519.9+ KB

# %%
data["label"]=data["label"].replace({"male":0,"female":1}) #replacing  values in the column for sex rappresentation in int

# %%
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
from scipy.stats import zscore
dataz=data.copy()
for col in list(dataz.columns):
    dataz[col] = zscore(dataz[col])
dataz
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0    -4.049248  0.427355 -4.224901 -2.576102 -5.693607 -0.214778  2.293306
# 1    -3.841053  0.611669 -3.999293 -2.486885 -5.588987 -0.258485  4.548056
# 2    -3.463066  1.603848 -4.095851 -2.706986 -3.928699  0.909326  6.513656
# 3    -0.992157  0.899998 -0.759454 -0.901418 -0.711205  0.632690 -0.449858
# 4    -1.530640  1.322561 -1.676948 -1.268395 -0.792029  1.005588 -0.480911
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163 -1.638842  1.658182 -0.877839 -1.873163 -0.999378  1.579141 -0.325020
# 3164 -2.162452  1.927682 -2.994482 -2.008095 -0.840021  1.820721 -0.577009
# 3165 -1.298773  2.322724 -0.051973 -2.199039 -0.017123  2.492666 -0.298044
# 3166 -1.245202  2.012196 -0.017728 -1.991852 -0.204021  2.153653 -0.365367
# 3167 -0.514746  2.147651 -0.070879 -1.446089  1.102679  2.254671 -0.338487
#
# ...

# %%
data['label'].value_counts().sort_index().plot.bar(figsize=(12,6))
plt.grid()
plt.show()

# %%
bins_struges=int(3.3*np.log(len(data['meanfreq'])))
bins_rice=int(2*len(data['meanfreq'])**(1/3))
plt.subplot(2,2,1)
plt.title('Struges ({} bins)'.format(bins_struges))
data['meanfreq'].plot.hist(figsize=(12,6), density='True', bins=bins_struges)
plt.grid()
plt.subplot(2,2,2)
plt.title('Rice ({} bins)'.format(bins_rice))
data['meanfreq'].plot.hist(figsize=(12,6), density='True', bins=bins_rice)
plt.grid()
plt.subplot(2,2,3)
data['IQR'].plot.hist(figsize=(12,6), density='True', bins=bins_struges)
plt.grid()
plt.subplot(2,2,4)
data['IQR'].plot.hist(figsize=(12,6), density='True', bins=bins_rice)
plt.grid()
plt.show()

# %%
plt.subplot(1,2,1)
plt.title('Struges ({} bins)'.format(bins_struges))
data['IQR'].plot.hist(figsize=(12,6), density='True', bins=bins_struges)
plt.grid()
plt.subplot(1,2,2)
plt.title('Rice ({} bins)'.format(bins_rice))
data['IQR'].plot.hist(figsize=(12,6), density='True', bins=bins_rice)
plt.grid()
plt.show()

# %%
dataz.boxplot(by='label',column=['meanfreq',"IQR"], figsize=(8,6))
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.subplot(121)
plt.title('Mean Freq')
dataz['meanfreq'].plot.density()
plt.subplot(122)
plt.title('IQR')
dataz['IQR'].plot.density()
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.subplot(121)
a=dataz['meanfreq'].plot.density(figsize=(12,6))
plt.hist(dataz['meanfreq'], density=True)
plt.grid()
plt.subplot(122)
b=dataz['IQR'].plot.density(figsize=(12,6))
plt.hist(dataz['IQR'], density=True)
plt.grid()
plt.show()

# %%
a=dataz[dataz['label']==-1]['meanfreq'].value_counts().sort_index().cumsum()
b=dataz[dataz['label']==1]['meanfreq'].value_counts().sort_index().cumsum()
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(a.index,a.values)
plt.plot(b.index,b.values)
plt.grid()
plt.legend(['F','M'])
c=dataz[dataz['label']==-1]['IQR'].value_counts().sort_index().cumsum()
d=dataz[dataz['label']==1]['meanfreq'].value_counts().sort_index().cumsum()
plt.subplot(122)
plt.plot(c.index,c.values)
plt.plot(d.index,d.values)
plt.grid()
plt.legend(['F','M'])
plt.show()
plt.show()

# %%
dataz.groupby('label')['meanfreq'].plot.hist(width=0.4, alpha=0.8, density=True, figsize=(16,6))
dataz.groupby('label')['meanfreq'].plot.density()
plt.legend(['F','M','F','M'])
plt.grid()
plt.show()

# %%
dataz.groupby('label')['IQR'].plot.hist(width=0.4, alpha=0.8, density=True, figsize=(16,6))
dataz.groupby('label')['IQR'].plot.density()
plt.legend(['F','M','F','M'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data['IQR'], data['meanfreq'], hue=data['label'])
plt.show()
